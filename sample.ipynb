# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Ethos

# %%
baseline_acc = [0.8, 0.84, 0.82, 0.88]
new_acc = [0.8, 0.89, 0.95, 0.92]
baseline_val = [0.8, 0.84, 0.82, 0.88]
new_val = [0.8, 0.86, 0.88, 0.9]
baseline_time = [2.5, 174.68, 920.221, 1273.025]
new_time = [1.6, 71.11, 352.9, 515.64]

# %%
epochs = list(range(1, 5))

# Create a figure with 3 subplots in 1 row
fig, axes = plt.subplots(1, 3, figsize=(18, 5))  # width 18, height 5

# Plot 1: Accuracy
axes[0].plot(epochs, baseline_acc, label="Baseline Accuracy")
axes[0].plot(epochs, new_acc, label="New Accuracy")
axes[0].set_xlabel("Round")
axes[0].set_ylabel("Accuracy")
axes[0].set_title("Training Accuracy")
axes[0].legend()

# Plot 2: Validation Accuracy
axes[1].plot(epochs, baseline_val, label="Baseline Validation Accuracy")
axes[1].plot(epochs, new_val, label="New Validation Accuracy")
axes[1].set_xlabel("Round")
axes[1].set_ylabel("Validation Accuracy")
axes[1].set_title("Validation Accuracy")
axes[1].legend()

# Plot 3: Time per Epoch
axes[2].plot(epochs, baseline_time, label="Baseline Time")
axes[2].plot(epochs, new_time, label="New Time")
axes[2].set_xlabel("Round")
axes[2].set_ylabel("Time (s)")
axes[2].set_title("Training Time per Epoch")
axes[2].legend()

plt.tight_layout()  # Adjust spacing
plt.show()

# %% [markdown]
# ### GPT-OSS-20B

# %%
baseline_acc = [0.87, 0.88, 0.89, 0.89, 0.89]
new_acc = [0.87, 0.928, 1, 1, 0.917]
baseline_val = [0.84, 0.84, 0.86, 0.84, 0.84]
new_val = [0.84, 0.92, 0.86, 0.86, 0.92]
baseline_time = [10.65,  205.57, 544.34, 668.65, 588.11]
new_time = [9.38, 228.06, 491.58, 513.19, 525.62]

# %%
epochs = list(range(1, 6))

# Create a figure with 3 subplots in 1 row
fig, axes = plt.subplots(1, 3, figsize=(18, 5))  # width 18, height 5

# Plot 1: Accuracy
axes[0].plot(epochs, baseline_acc, label="Baseline Accuracy")
axes[0].plot(epochs, new_acc, label="New Accuracy")
axes[0].set_xlabel("Round")
axes[0].set_ylabel("Accuracy")
axes[0].set_title("Training Accuracy")
axes[0].legend()

# Plot 2: Validation Accuracy
axes[1].plot(epochs, baseline_val, label="Baseline Validation Accuracy")
axes[1].plot(epochs, new_val, label="New Validation Accuracy")
axes[1].set_xlabel("Round")
axes[1].set_ylabel("Validation Accuracy")
axes[1].set_title("Validation Accuracy")
axes[1].legend()

# Plot 3: Time per Epoch
axes[2].plot(epochs, baseline_time, label="Baseline Time")
axes[2].plot(epochs, new_time, label="New Time")
axes[2].set_xlabel("Round")
axes[2].set_ylabel("Time (s)")
axes[2].set_title("Training Time per Epoch")
axes[2].legend()

plt.tight_layout()  # Adjust spacing
plt.show()

# %% [markdown]
# # Nai Ơ

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import ttest_ind

# %% [markdown]
# ## ProTeGi

# %%
pass_1 = {
    "training_acc": [0.60546875, 0.6640625, 0.7083333333333334, 0.6875, 0.71875, 0.671875, 0.6875],
    "val_acc": [0.5582655826558266, 0.6097560975609756, 0.6287262872628726, 0.6178861788617886, 0.6178861788617886, 0.6178861788617886, 0.6178861788617886],
    "test_acc": [0.6550976138828634]
}
pass_2 = {
    "training_acc": [0.60546875, 0.63671875, 0.71875, 0.7083333333333334, 0.6875, 0.6979166666666666, 0.71875],
    "val_acc": [0.5555555555555556, 0.5907859078590786, 0.6233062330623306, 0.6151761517615176, 0.6395663956639567, 0.6260162601626016, 0.6558265582655827],
    "test_acc": [0.6898047722342733]
}
pass_3 = {
    "training_acc": [0.609375, 0.6484375, 0.7083333333333334, 0.6875, 0.734375, 0.7421875, 0.6875],
    "val_acc": [0.5582655826558266, 0.6124661246612466, 0.5907859078590786, 0.6287262872628726, 0.5989159891598916, 0.6233062330623306, 0.5799457994579946],
    "test_acc": [0.6442516268980477]
}
pass_4 = {
    "training_acc": [0.60546875, 0.6484375, 0.71875, 0.6979166666666666, 0.6979166666666666, 0.6875, 0.6875],
    "val_acc": [0.5582655826558266, 0.5907859078590786, 0.6151761517615176, 0.6097560975609756, 0.6151761517615176, 0.6151761517615176, 0.6287262872628726],
    "test_acc": [0.6377440347071583]
}
pass_5 = {
    "training_acc": [0.60546875, 0.65234375, 0.6979166666666666, 0.6875, 0.6875, 0.6953125, 0.71875],
    "val_acc": [0.5582655826558266, 0.5853658536585366, 0.6097560975609756, 0.6260162601626016, 0.6476964769647696, 0.6422764227642277, 0.6070460704607046],
    "test_acc": [0.6377440347071583]
}

# %% [markdown]
# ## Ours

# %%
ours_pass_1 = {
    "training_acc": [0.60546875, 0.5989583333333334, 0.734375, 0.7109375, 0.7265625, 0.64375, 0.65],
    "val_acc": [0.5582655826558266, 0.6585365853658537, 0.6476964769647696, 0.6531165311653117, 0.6531165311653117, 0.6341463414634146, 0.6368563685636857],
    "test_acc": [0.6811279826464208]
}

ours_pass_2 = {
    "training_acc": [0.609375, 0.6041666666666666, 0.6770833333333334, 0.6875, 0.65625, 0.7291666666666666, 0.6796875],
    "val_acc": [0.5582655826558266, 0.6151761517615176, 0.5853658536585366, 0.6287262872628726, 0.6287262872628726, 0.6341463414634146, 0.6422764227642277],
    "test_acc": [0.6616052060737527]
}

ours_pass_3 = {
    "training_acc": [0.54296875, 0.64453125, 0.6953125, 0.6979166666666666, 0.6979166666666666, 0.6875, 0.734375],
    "val_acc": [0.5582655826558266, 0.6449864498644986, 0.6531165311653117, 0.6368563685636857, 0.6368563685636857, 0.6287262872628726, 0.6639566395663956],
    "test_acc": [0.6789587852494577]
}

ours_pass_4 = {
    "training_acc": [0.62890625, 0.6354166666666666, 0.71875, 0.70625, 0.65625, 0.66875, 0.6953125],
    "val_acc": [0.5582655826558266, 0.6504065040650406, 0.6558265582655827, 0.6720867208672087, 0.6531165311653117, 0.6476964769647696, 0.6531165311653117],
    "test_acc": [0.6832971800433839]
}

ours_pass_5 = {
    "training_acc": [0.6015625, 0.6666666666666666, 0.6770833333333334, 0.7916666666666666, 0.75, 0.6875, 0.78125],
    "val_acc": [0.5555555555555556, 0.6558265582655827, 0.6693766937669376, 0.6802168021680217, 0.6720867208672087, 0.6747967479674797, 0.6964769647696477],
    "test_acc": [0.7136659436008677]
}

# %%
protegi_test_samples = np.array([pass_1["test_acc"][0], pass_2["test_acc"][0], pass_3["test_acc"][0], pass_4["test_acc"][0], pass_5["test_acc"][0]])
ours_test_samples = np.array([ours_pass_1["test_acc"][0], ours_pass_2["test_acc"][0], ours_pass_3["test_acc"][0], ours_pass_4["test_acc"][0], ours_pass_5["test_acc"][0]])

# %%
mean_protegi_test_acc = protegi_test_samples.mean()
mean_protegi_test_acc
# Out:
# np.float64(0.6529284164859004)

# %%
mean_ours_test_acc = ours_test_samples.mean()
mean_ours_test_acc
# Out:
# np.float64(0.6837310195227765)

# %%
group1 = protegi_test_samples
group2 = ours_test_samples

t_stat, p_value = ttest_ind(group1, group2)

print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: -2.3920507778786737
# p-value: 0.04371569420447489

# %%
epochs = list(range(0, 7))

# Create a figure with 2 rows and 3 columns
fig, axes = plt.subplots(2, 3, figsize=(12, 8))  # wider & taller for 2 rows

# Flatten axes array for easy indexing
axes = axes.flatten()

axes[0].plot(epochs, pass_1["val_acc"], marker='o', label="ProTeGi")
axes[0].plot(epochs, ours_pass_1["val_acc"], marker='o', label="Ours")
axes[0].set_xlabel("Round")
axes[0].set_ylabel("Validation Accuracy")
axes[0].set_title("Experiment 1")
axes[0].legend()

axes[1].plot(epochs, pass_2["val_acc"], marker='o', label="ProTeGi")
axes[1].plot(epochs, ours_pass_2["val_acc"], marker='o', label="Ours")
axes[1].set_xlabel("Round")
axes[1].set_ylabel("Validation Accuracy")
axes[1].set_title("Experiment 2")
axes[1].legend()

axes[2].plot(epochs, pass_3["val_acc"], marker='o', label="ProTeGi")
axes[2].plot(epochs, ours_pass_3["val_acc"], marker='o', label="Ours")
axes[2].set_xlabel("Round")
axes[2].set_ylabel("Validation Accuracy")
axes[2].set_title("Experiment 3")
axes[2].legend()

axes[3].plot(epochs, pass_4["val_acc"], marker='o', label="ProTeGi")
axes[3].plot(epochs, ours_pass_4["val_acc"], marker='o', label="Ours")
axes[3].set_xlabel("Round")
axes[3].set_ylabel("Validation Accuracy")
axes[3].set_title("Experiment 4")
axes[3].legend()

axes[4].plot(epochs, pass_5["val_acc"], marker='o', label="ProTeGi")
axes[4].plot(epochs, ours_pass_5["val_acc"], marker='o', label="Ours")
axes[4].set_xlabel("Round")
axes[4].set_ylabel("Validation Accuracy")
axes[4].set_title("Experiment 5")
axes[4].legend()

# Remove the unused 6th subplot
axes[5].axis("off")

# Global title
fig.suptitle("Liar Experiments", fontsize=16)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Comparision

# %%
metrics = pd.DataFrame({
    "ProTeGi": [mean_protegi_test_acc.round(2)],
    "Ours": [mean_ours_test_acc.round(2)]
}, index=['Liar'])
metrics
# Out:
#       ProTeGi  Ours
# Liar     0.65  0.68
